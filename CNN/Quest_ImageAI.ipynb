# %% [markdown]
# <a href="https://colab.research.google.com/github/mlukan/GDA3B2021/blob/main/CNN/Quest_ImageAI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Preparation

# %% [markdown]
# Install ImageAI.

# %%
# !pip3 install https://github.com/OlafenwaMoses/ImageAI/releases/download/2.0.2/imageai-2.0.2-py3-none-any.whl
# Out:
# ...
#      |████████████████████████████████| 153kB 23.0MB/s
# ...
#   Found existing installation: imageai 2.1.6
#     Uninstalling imageai-2.1.6:
#       Successfully uninstalled imageai-2.1.6
# ...

# %% [markdown]
# Download the weights generated by the ResNet model, trained on the ImageNet dataset.

# %%
import urllib.request

import os
urllib.request.urlretrieve('https://github.com/OlafenwaMoses/ImageAI/releases/download/essentials-v5/resnet50_imagenet_tf.2.0.h5', 'resnet.h5')
# Out:
# ('resnet.h5', <http.client.HTTPMessage at 0x7efff3f5bed0>)

# %% [markdown]
# Download the picture which we will ateempt to classify using the model.

# %%
urllib.request.urlretrieve('https://upload.wikimedia.org/wikipedia/commons/b/bb/Kittyply_edit1.jpg','cat.jpg')
# Out:
# ('cat.jpg', <http.client.HTTPMessage at 0x7f003a98f8d0>)

# %%
# !pip3 install imageai --upgrade
# Out:
# ...
#   Using cached https://files.pythonhosted.org/packages/73/44/3d5d8ef572888025666eec284e85f9243faf06ca8c12085dcff1ca9754ed/imageai-2.1.6-py3-none-any.whl
# ...
#   Found existing installation: imageai 2.0.2
#     Uninstalling imageai-2.0.2:
#       Successfully uninstalled imageai-2.0.2
# ...

# %% [markdown]
# # Tasks

# %% [markdown]
# Refer to the ImageAI [documentation](https://imageai.readthedocs.io/en/latest/) to complete the tasks.
#
# *   Create an instance of `ImagePrediction()`.
# *   Since we will be using weights trained on ResNet, set the model type to ResNet.
# *   Set model path to the pre-trained weights you downloaded earlier.
# *   Finally, load the model.

# %%
# your code:
import imageai
from imageai.Classification import ImageClassification
prediction = ImageClassification()
prediction.setModelTypeAsResNet50()
prediction.setModelPath("./resnet.h5")
prediction.loadModel()

# %%
import os
os.listdir(os.getcwd())
# Out:
# ['.config', 'resnet.h5', 'cat.jpg', 'sample_data']

# %% [markdown]
# Return top 3 predictions and their corresponding probabilities for the image.

# %%
# your code:
predictions, probabilities = prediction.classifyImage("cat.jpg", result_count=3)

# %%
[print(p) for p in zip(predictions,probabilities)]
# Out:
# ('tabby', 40.728759765625)
# ('tiger_cat', 30.614012479782104)
# ('lynx', 16.609205305576324)
# [None, None, None]
